# %%
# Import necessary libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
tips = sns.load_dataset("tips")

# Explore the dataset (optional)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#check tail
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
#check info
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Select features (predictors) and target variable
# Using total_bill as the predictor
X = tips[['total_bill']]
# Predicting tip amount
y=tips['tip']

# %%
#check head
y.head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
#checking X_trian
X_test.head()
# Out:
#      total_bill
# 67         3.07
# 243       18.78
# 206       26.59
# 122       14.26
# 89        21.16

# %%
# Create a linear regression model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
# Fit the model to the training data
model.fit(X_train,y_train)

# Make predictions on the test data
y_pred= model.predict(X_test)

# %%
y_pred
# Out:
# array([1.37924964, 2.8639833 , 3.60209723, 2.4368034 , 3.0889143 ,
#        1.82060586, 2.15138675, 3.06434201, 2.45759535, 3.41307958,
#        2.23833487, 2.0427016 , 3.91775671, 3.47167505, 5.891101  ,
#        3.23162263, 3.29399846, 2.06160336, 2.28842455, 3.65785744,
#        3.93760356, 2.76947447, 2.63149159, 3.27887705, 2.26385225,
#        2.09562654, 3.02559339, 3.47829067, 2.8554775 , 3.93004286,
#        2.31772228, 3.96217586, 2.13059481, 4.47535879, 4.38084996,
#        2.35741599, 4.04439854, 2.8233445 , 2.69292232, 2.14477113,
#        3.36488008, 3.0407148 , 3.21461104, 2.50768502, 3.04449516,
#        3.82702824, 3.3629899 , 4.42148875, 2.94620598])

# %%
# Evaluate the model
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
print(mse)
# Out:
# 1.229861539630728

# %%
print(r2)
# Out:
# 0.53268096783414

# %%
# Visualize the linear regression line
plt.scatter(X_test,y_test,color="blue")
plt.plot(X_test,y_pred,color="red")
plt.xlabel("total_bill")
plt.ylabel("tip")
plt.title("Linear Regression : total_bill vs tip amount")
plt.show()
